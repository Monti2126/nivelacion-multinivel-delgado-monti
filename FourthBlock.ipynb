# %% [markdown]
# <a href="https://colab.research.google.com/github/Monti2126/nivelacion-multinivel-delgado-monti/blob/main/FourthBlock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Bloque - 4

# %%
# Funciones RPG



def calcular_dano(ataque: int, defensa: int) -> int:

    '''Retorna el dano real (minimo 1)'''

    dano = ataque - defensa

    return dano if dano > 0 else 1



def aplicar_curacion(

    vida: float, cur: float, max_vida: float) -> float:

    '''Cura sin pasar el maximo'''

    nueva = vida + cur

    return min(nueva, max_vida)



def mostrar_estado(

    nombre: str, vida: float, nivel: int):

    '''Imprime el estado del personaje'''

    print(f'{nombre} [Nv{nivel}] HP: {vida:.0f}')


def subir_nivel(xp_actual: int, xp_necesario: int, nivel_actual: int):
  if xp_actual >= xp_necesario:
    nivel_actual += 1
    print('Has alcanzado un nuevo nivel')
  return nivel_actual

# Prueba


d = calcular_dano(20, 8)

print(f'Dano: {d}')

v = aplicar_curacion(40, 80, 100)

mostrar_estado('Frodo', v, 3)
print('Parametros: xp_actual=110, xp_Necesario=100, nivel_actual=3')
print(subir_nivel(110, 100, 3))
print('Parametros: xp_actual=80, xp_Necesario=100, nivel_actual=3')
print(subir_nivel(80, 100, 3))
# Out:
# Dano: 12
# Frodo [Nv3] HP: 100
# Parametros: xp_actual=110, xp_Necesario=100, nivel_actual=3
# Has alcanzado un nuevo nivel
# 4
# Parametros: xp_actual=80, xp_Necesario=100, nivel_actual=3
# 3
