# %%
print("Setup inicial OK")
# Out:
# Setup inicial OK

# %%
nombre = 'Aragorn'
nivel = 1
vida = 100.0
vida_maxima = 100.0
esta_vivo = True
clase = 'Guerrero'
puntos_ataque = 15
puntos_defensa = 10

# %%
print(type(nombre))
print(type(nivel))
print(type(vida))
print(type(esta_vivo))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(f'{nombre} (Nv.{nivel}) - Vida: {vida}')
# Out:
# Aragorn (Nv.1) - Vida: 100.0

# %%
ataque = 15
dano = float(ataque) * 1.5
print(dano)
# Out:
# 22.5

# %%
nom = input('Nombre: ')
niv = int(input('Nivel: '))
print(f'{nom} Nv.{niv}')
# Out:
# Nombre: Jhon Montaño
# Nivel: 2
# Jhon Montaño Nv.2

# %%
vida = 87.5
print(f'Vida: {vida:.1f}%')
# Out:
# Vida: 87.5%

# %%
nombre = 'Gandalf'
clase = 'Mago'
nivel = 5
vida = 80.0
mana = 120

print(f'{nombre} [{clase}] Nv.{nivel} | Vida: {vida} | Mana: {mana}')
# Out:
# Gandalf [Mago] Nv.5 | Vida: 80.0 | Mana: 120
